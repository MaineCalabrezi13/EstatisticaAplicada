# %% [markdown]
# <a href="https://colab.research.google.com/github/MaineCalabrezi13/EstatisticaAplicada/blob/main/Distribui%C3%A7%C3%A3oFrequencia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
dados = np.array([
    160, 165, 167, 164, 160, 166, 160, 161, 150, 152, 173, 160, 155,
    164, 168, 162, 161, 168, 163, 156, 155, 169, 151, 170, 164,
    155, 152, 163, 160, 155, 157, 156, 158, 158, 161, 154, 161, 156, 172, 153
])

# %%
minimo = dados.min()
minimo
# Out:
# np.int64(150)

# %%
maximo = dados.max()
maximo
# Out:
# np.int64(173)

# %%
np.unique(dados, return_counts=True)
# Out:
# (array([150, 151, 152, 153, 154, 155, 156, 157, 158, 160, 161, 162, 163,
#         164, 165, 166, 167, 168, 169, 170, 172, 173]),
#  array([1, 1, 2, 1, 1, 4, 3, 1, 2, 5, 4, 1, 2, 3, 1, 1, 1, 2, 1, 1, 1, 1]))

# %%
plt.bar(dados, dados)
# Out:
# <BarContainer object of 40 artists>

# %%
n = len(dados)
n
# Out:
# 40

# %%
i = 1 + 3.3 * np.log10(n)
i
# Out:
# np.float64(6.286797971382276)

# %%
i = round(i)
i
# Out:
# 6

# %%
AA = maximo - minimo
AA
# Out:
# np.int64(23)

# %%
h = AA / i
h
# Out:
# np.float64(3.8333333333333335)

# %%
import math
h = math.ceil(h)
h
# Out:
# 4
