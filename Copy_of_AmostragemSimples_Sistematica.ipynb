# %% [markdown]
# <a href="https://colab.research.google.com/github/MaineCalabrezi13/EstatisticaAplicada/blob/main/Copy_of_AmostragemSimples_Sistematica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random
import numpy as np

# %%
dataset=pd.read_csv('census.csv', delimiter=';')

# %%
dataset.shape
# Out:
# (32561, 15)

# %%
dataset.head()
# Out:
#    age          workclass  final-weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loos  hour-per-week  native-country  income
# 0          2174             0             40   United-States   <=50K
# 1             0             0             13   United-States   <=50K
# 2             0             0             40   United-States   <=50K
# 3             0             0             40   United-States   <=50K
# 4             0             0             40            Cuba   <=50K

# %%
dataset.tail()
# Out:
#        age      workclass  final-weight    education  education-num  \
# 32556   27        Private        257302   Assoc-acdm             12
# 32557   40        Private        154374      HS-grad              9
# 32558   58        Private        151910      HS-grad              9
# 32559   22        Private        201490      HS-grad              9
# 32560   52   Self-emp-inc        287927      HS-grad              9
#
#             marital-status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital-gain  capital-loos  hour-per-week  native-country  income
# 32556             0             0             38   United-States   <=50K
# 32557             0             0             40   United-States    >50K
# 32558             0             0             40   United-States   <=50K
# 32559             0             0             20   United-States   <=50K
# 32560         15024             0             40   United-States    >50K

# %%
df_amostra_aleatoria_simples = dataset.sample(n = 100)
df_amostra_aleatoria_simples.shape
# Out:
# (100, 15)

# %%
df_amostra_aleatoria_simples.head()
# Out:
#        age          workclass  final-weight      education  education-num  \
# 24274   67   Self-emp-not-inc        123393        HS-grad              9
# 22443   44            Private        210013        HS-grad              9
# 19595   51            Private         87205      Bachelors             13
# 2837    69   Self-emp-not-inc         69306   Some-college             10
# 4028    26            Private        195216        HS-grad              9
#
#             marital-status         occupation    relationship    race  \
# 24274   Married-civ-spouse   Transport-moving         Husband   White
# 22443   Married-civ-spouse   Transport-moving         Husband   White
# 19595   Married-civ-spouse       Adm-clerical            Wife   White
# 2837    Married-civ-spouse      Other-service            Wife   White
# 4028              Divorced      Other-service   Not-in-family   White
#
#            sex  capital-gain  capital-loos  hour-per-week  native-country  \
# 24274     Male          6418             0             58   United-States
# 22443     Male             0             0             40   United-States
# 19595   Female          7688             0             20   United-States
# 2837    Female             0             0             15   United-States
# 4028    Female             0             0             12   United-States
#
#        income
# 24274    >50K
# 22443    >50K
# 19595    >50K
# 2837    <=50K
# 4028    <=50K

# %%
df_amostra_aleatoria_simples = dataset.sample(n = 100,)
df_amostra_aleatoria_simples.shape
# Out:
#        age     workclass  final-weight      education  education-num  \
# 15178   27       Private        369522        HS-grad              9
# 14091   25       Private        169124      Bachelors             13
# 5077    35       Private        170797      Bachelors             13
# 24910   55     Local-gov        171328   Some-college             10
# 19089   58   Federal-gov         30111   Some-college             10
#
#                marital-status          occupation    relationship  \
# 15178           Never-married   Machine-op-inspct       Own-child
# 14091           Never-married        Adm-clerical       Own-child
# 5077                 Divorced       Other-service   Not-in-family
# 24910   Married-spouse-absent        Adm-clerical       Unmarried
# 19089                 Widowed      Prof-specialty       Unmarried
#
#                       race      sex  capital-gain  capital-loos  \
# 15178                White     Male             0             0
# 14091                White     Male             0             0
# 5077                 White   Female             0             0
# 24910                Black   Female             0             0
# 19089   Amer-Indian-Eskimo   Female             0             0
#
#        hour-per-week  native-country  income
# 15178             45   United-States   <=50K
# 14091             40   United-States   <=50K
# 5077              40   United-States   <=50K
# 24910             35   United-States   <=50K
# 19089             40   United-States   <=50K

# %%
df_amostra_aleatoria_simples.head()
# Out:
#        age     workclass  final-weight      education  education-num  \
# 15178   27       Private        369522        HS-grad              9
# 14091   25       Private        169124      Bachelors             13
# 5077    35       Private        170797      Bachelors             13
# 24910   55     Local-gov        171328   Some-college             10
# 19089   58   Federal-gov         30111   Some-college             10
#
#                marital-status          occupation    relationship  \
# 15178           Never-married   Machine-op-inspct       Own-child
# 14091           Never-married        Adm-clerical       Own-child
# 5077                 Divorced       Other-service   Not-in-family
# 24910   Married-spouse-absent        Adm-clerical       Unmarried
# 19089                 Widowed      Prof-specialty       Unmarried
#
#                       race      sex  capital-gain  capital-loos  \
# 15178                White     Male             0             0
# 14091                White     Male             0             0
# 5077                 White   Female             0             0
# 24910                Black   Female             0             0
# 19089   Amer-Indian-Eskimo   Female             0             0
#
#        hour-per-week  native-country  income
# 15178             45   United-States   <=50K
# 14091             40   United-States   <=50K
# 5077              40   United-States   <=50K
# 24910             35   United-States   <=50K
# 19089             40   United-States   <=50K

# %%
df_amostra_aleatoria_simples = dataset.sample(n = 100, random_state= 1)
df_amostra_aleatoria_simples.shape
# Out:
# (100, 15)

# %%
df_amostra_aleatoria_simples.head()
# Out:
#        age          workclass  final-weight   education  education-num  \
# 9646    62   Self-emp-not-inc         26911     7th-8th              4
# 709     18            Private        208103        11th              7
# 7385    25            Private        102476   Bachelors             13
# 16671   33            Private        511517     HS-grad              9
# 21932   36            Private        292570        11th              7
#
#             marital-status          occupation     relationship    race  \
# 9646               Widowed       Other-service    Not-in-family   White
# 709          Never-married       Other-service   Other-relative   White
# 7385         Never-married     Farming-fishing        Own-child   White
# 16671   Married-civ-spouse      Prof-specialty          Husband   White
# 21932        Never-married   Machine-op-inspct        Unmarried   White
#
#            sex  capital-gain  capital-loos  hour-per-week  native-country  \
# 9646    Female             0             0             66   United-States
# 709       Male             0             0             25   United-States
# 7385      Male         27828             0             50   United-States
# 16671     Male             0             0             40   United-States
# 21932   Female             0             0             40   United-States
#
#        income
# 9646    <=50K
# 709     <=50K
# 7385     >50K
# 16671   <=50K
# 21932   <=50K

# %%
def df_amostra_aleatoria_simples(dataset, amostras):
  return dataset.sample(n = amostras)

# %%
df_amostra_aleatoria_simples = df_amostra_aleatoria_simples(dataset, 100)
df_amostra_aleatoria_simples.shape
# Out:
# (100, 15)

# %%
df_amostra_aleatoria_simples.head()
# Out:
#        age   workclass  final-weight   education  education-num  \
# 27397   32   Local-gov        114733   Bachelors             13
# 17618   25     Private        108301     HS-grad              9
# 25844   29     Private        367329     HS-grad              9
# 5399    32     Private         53260     HS-grad              9
# 14409   28     Private        301654   Bachelors             13
#
#             marital-status          occupation    relationship    race  \
# 27397             Divorced      Prof-specialty       Unmarried   White
# 17618            Separated       Other-service       Unmarried   White
# 25844   Married-civ-spouse   Machine-op-inspct         Husband   White
# 5399              Divorced       Other-service       Unmarried   Other
# 14409        Never-married      Prof-specialty   Not-in-family   White
#
#            sex  capital-gain  capital-loos  hour-per-week  native-country  \
# 27397   Female             0             0             35   United-States
# 17618   Female             0             0             20   United-States
# 25844     Male             0             0             40   United-States
# 5399    Female             0             0             28   United-States
# 14409   Female             0             0             40   United-States
#
#        income
# 27397   <=50K
# 17618   <=50K
# 25844   <=50K
# 5399    <=50K
# 14409   <=50K

# %%
def amostragem_aleatoria_simples(dataset, amostras):
  return dataset.sample(n = amostras, random_state=1)

# %%
df_amostra_aleatoria_simples = amostragem_aleatoria_simples(dataset, 100)
df_amostra_aleatoria_simples.shape
# Out:
# (100, 15)

# %%
df_amostra_aleatoria_simples.head()
# Out:
#        age          workclass  final-weight   education  education-num  \
# 9646    62   Self-emp-not-inc         26911     7th-8th              4
# 709     18            Private        208103        11th              7
# 7385    25            Private        102476   Bachelors             13
# 16671   33            Private        511517     HS-grad              9
# 21932   36            Private        292570        11th              7
#
#             marital-status          occupation     relationship    race  \
# 9646               Widowed       Other-service    Not-in-family   White
# 709          Never-married       Other-service   Other-relative   White
# 7385         Never-married     Farming-fishing        Own-child   White
# 16671   Married-civ-spouse      Prof-specialty          Husband   White
# 21932        Never-married   Machine-op-inspct        Unmarried   White
#
#            sex  capital-gain  capital-loos  hour-per-week  native-country  \
# 9646    Female             0             0             66   United-States
# 709       Male             0             0             25   United-States
# 7385      Male         27828             0             50   United-States
# 16671     Male             0             0             40   United-States
# 21932   Female             0             0             40   United-States
#
#        income
# 9646    <=50K
# 709     <=50K
# 7385     >50K
# 16671   <=50K
# 21932   <=50K

# %%
def amostragem_aleatoria_simples(dataset, amostras):
  return dataset.sample(n = amostras, random_state=2)

# %%
df_amostra_aleatoria_simples = amostragem_aleatoria_simples(dataset, 100)
df_amostra_aleatoria_simples.shape
# Out:
# (100, 15)

# %%
df_amostra_aleatoria_simples.head()
# Out:
#        age     workclass  final-weight      education  education-num  \
# 16054   42     State-gov        160369        HS-grad              9
# 32382   44     Local-gov        150171        HS-grad              9
# 10749   39     Local-gov        256997      Bachelors             13
# 15377   39       Private        147548        HS-grad              9
# 29660   29   Federal-gov        106179   Some-college             10
#
#             marital-status        occupation    relationship    race      sex  \
# 16054        Never-married   Protective-serv   Not-in-family   White     Male
# 32382             Divorced      Adm-clerical       Unmarried   White   Female
# 10749   Married-civ-spouse      Craft-repair         Husband   White     Male
# 15377   Married-civ-spouse      Craft-repair         Husband   White     Male
# 29660        Never-married    Prof-specialty   Not-in-family   White   Female
#
#        capital-gain  capital-loos  hour-per-week  native-country  income
# 16054             0             0             40   United-States    >50K
# 32382             0             0             40   United-States   <=50K
# 10749             0             0             40   United-States   <=50K
# 15377             0             0             40   United-States   <=50K
# 29660             0          1408             40   United-States   <=50K

# %%
dataset.shape
# Out:
# (32561, 15)

# %%
len(dataset)
# Out:
# 32561

# %%
dataset.shape
# Out:
# (32561, 15)

# %%
len(dataset)/100
# Out:
# 325.61

# %%
dataset.shape
# Out:
# (32561, 15)

# %%
len(dataset)//100
# Out:
# 325

# %%
dataset.shape
# Out:
# (32561, 15)

# %%
len(dataset)//100
# Out:
# 325

# %%
random.randint(0,325)
# Out:
# 23

# %%
dataset.shape
# Out:
# (32561, 15)

# %%
len(dataset)//100
# Out:
# 325

# %%
random.seed(1)
random.randint(0,325)
# Out:
# 68

# %%
dataset.shape
# Out:
# (32561, 15)

# %%
len(dataset)//100
# Out:
# 325

# %%
random.seed(1)
random.randint(0,325)
# Out:
# 68

# %%
68+325
# Out:
# 393

# %%
len(dataset)//100
# Out:
# 325

# %%
random.seed(1)
random.randint(0,325)
# Out:
# 68

# %%
68 + 325
# Out:
# 393

# %%
393+325
# Out:
# 718

# %%
68+325
# Out:
# 393

# %%
393+325
# Out:
# 718

# %%
np.arange(68, len(dataset), step=325)
# Out:
# array([   68,   393,   718,  1043,  1368,  1693,  2018,  2343,  2668,
#         2993,  3318,  3643,  3968,  4293,  4618,  4943,  5268,  5593,
#         5918,  6243,  6568,  6893,  7218,  7543,  7868,  8193,  8518,
#         8843,  9168,  9493,  9818, 10143, 10468, 10793, 11118, 11443,
#        11768, 12093, 12418, 12743, 13068, 13393, 13718, 14043, 14368,
#        14693, 15018, 15343, 15668, 15993, 16318, 16643, 16968, 17293,
#        17618, 17943, 18268, 18593, 18918, 19243, 19568, 19893, 20218,
#        20543, 20868, 21193, 21518, 21843, 22168, 22493, 22818, 23143,
#        23468, 23793, 24118, 24443, 24768, 25093, 25418, 25743, 26068,
#        26393, 26718, 27043, 27368, 27693, 28018, 28343, 28668, 28993,
#        29318, 29643, 29968, 30293, 30618, 30943, 31268, 31593, 31918,
#        32243])

# %%
def amostragem_sistematica(dataset, amostras):
  intervalo = len(dataset) // amostras
  random.seed(1)
  inicio = random.randint(0, intervalo)
  indices = np.arange(inicio, len(dataset), step = intervalo)
  amostragem_sistematica = dataset.iloc[indices]
  return amostragem_sistematica

# %%
df_amostra_sistematica = amostragem_sistematica(dataset,100)
df_amostra_sistematica.shape
# Out:
# (100, 15)

# %%
df_amostra_sistematica.head()
# Out:
#       age      workclass  final-weight      education  education-num  \
# 68     49   Self-emp-inc        191681   Some-college             10
# 393    34      State-gov         98101      Bachelors             13
# 718    22        Private        214399   Some-college             10
# 1043   44        Private        167005      Bachelors             13
# 1368   52        Private        152234        HS-grad              9
#
#            marital-status        occupation relationship                 race  \
# 68     Married-civ-spouse   Exec-managerial      Husband                White
# 393    Married-civ-spouse   Exec-managerial      Husband                White
# 718         Never-married             Sales    Own-child                White
# 1043   Married-civ-spouse   Exec-managerial      Husband                White
# 1368   Married-civ-spouse   Exec-managerial      Husband   Asian-Pac-Islander
#
#           sex  capital-gain  capital-loos  hour-per-week  native-country  \
# 68       Male             0             0             50   United-States
# 393      Male          7688             0             45               ?
# 718    Female             0             0             15   United-States
# 1043     Male          7688             0             60   United-States
# 1368     Male         99999             0             40           Japan
#
#       income
# 68      >50K
# 393     >50K
# 718    <=50K
# 1043    >50K
# 1368    >50K
